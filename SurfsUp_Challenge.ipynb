# %%
# Dependencies
import numpy as np

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

import numpy as np
import pandas as pd

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 

june_q = session.query(Measurement.date, Measurement.tobs).filter(extract('month', Measurement.date)==6)

# %%
#  3. Convert the June temperatures to a list.
june_temps = june_q.all()
june_temps
# Out:
# [('2010-06-01', 78.0),
#  ('2010-06-02', 76.0),
#  ('2010-06-03', 78.0),
#  ('2010-06-04', 76.0),
#  ('2010-06-05', 77.0),
#  ('2010-06-06', 78.0),
#  ('2010-06-07', 77.0),
#  ('2010-06-08', 78.0),
#  ('2010-06-09', 78.0),
#  ('2010-06-10', 79.0),
#  ('2010-06-11', 78.0),
#  ('2010-06-12', 78.0),
#  ('2010-06-13', 78.0),
#  ('2010-06-14', 77.0),
#  ('2010-06-15', 78.0),
#  ('2010-06-16', 78.0),
#  ('2010-06-17', 77.0),
#  ('2010-06-18', 77.0),
#  ('2010-06-19', 82.0),
#  ('2010-06-20', 78.0),
#  ('2010-06-21', 78.0),
#  ('2010-06-22', 78.0),
#  ('2010-06-23', 78.0),
#  ('2010-06-24', 78.0),
#  ('2010-06-25', 77.0),
#  ('2010-06-26', 76.0),
#  ('2010-06-27', 78.0),
#  ('2010-06-28', 78.0),
#  ('2010-06-29', 78.0),
#  ('2010-06-30', 78.0),
#  ('2011-06-01', 77.0),
#  ('2011-06-02', 78.0),
#  ('2011-06-03', 73.0),
#  ('2011-06-04', 70.0),
#  ('2011-06-05', 76.0),
#  ('2011-06-06', 77.0),
#  ('2011-06-07', 77.0),
#  ('2011-06-08', 77.0),
#  ('2011-06-09', 77.0),
#  ('2011-06-10', 78.0),
# ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
june_temp_df = pd.DataFrame(june_temps, columns=['date','June, ℉'])
june_temp_df.set_index('date', inplace=True)
june_temp_df.head()
# Out:
#             June, ℉
# date
# 2010-06-01     78.0
# 2010-06-02     76.0
# 2010-06-03     78.0
# 2010-06-04     76.0
# 2010-06-05     77.0

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
june_temp_df.describe()
# Out:
#            June, ℉
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.

december_q = session.query(Measurement.date, Measurement.tobs).filter(extract('month', Measurement.date)==12)

# %%
# 7. Convert the December temperatures to a list.
december_temps = december_q.all()

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
december_temp_df = pd.DataFrame(december_temps, columns=['date','December, ℉'])
december_temp_df.set_index('date', inplace=True)
december_temp_df.head()
# Out:
#             December, ℉
# date
# 2010-12-01         76.0
# 2010-12-03         74.0
# 2010-12-04         74.0
# 2010-12-06         64.0
# 2010-12-07         64.0

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
december_temp_df.describe()
# Out:
#        December, ℉
# count  1517.000000
# mean     71.041529
# std       3.745920
# min      56.000000
# 25%      69.000000
# 50%      71.000000
# 75%      74.000000
# max      83.000000

# %% [markdown]
# # Additional queries for deliverable 3

# %%
december_prcp = session.query(Measurement.date, Measurement.prcp).filter(extract('month', Measurement.date)==12).all()
december_prcp_df = pd.DataFrame(december_prcp, columns=['date','precipitation in December'])
december_prcp_df.set_index('date', inplace=True)
december_prcp_df.describe()
# Out:
#        precipitation in December
# count                1405.000000
# mean                    0.216819
# std                     0.541399
# min                     0.000000
# 25%                     0.000000
# 50%                     0.030000
# 75%                     0.150000
# max                     6.420000

# %%
june_prcp = session.query(Measurement.date, Measurement.prcp).filter(extract('month', Measurement.date)==6).all()
june_prcp_df = pd.DataFrame(june_prcp, columns=['date','precipitation in June'])
june_prcp_df.set_index('date', inplace=True)
june_prcp_df.describe()
# Out:
#        precipitation in June
# count            1574.000000
# mean                0.136360
# std                 0.335731
# min                 0.000000
# 25%                 0.000000
# 50%                 0.020000
# 75%                 0.120000
# max                 4.430000

# %%
march_temp = session.query(Measurement.date, Measurement.tobs).filter(extract('month', Measurement.date)==3).all()
march_temp_df = pd.DataFrame(march_temp, columns=['date','March, ℉'])
march_temp_df.set_index('date', inplace=True)
march_temp_df.describe()
# Out:
#           March, ℉
# count  1693.000000
# mean     70.059067
# std       3.845271
# min      56.000000
# 25%      68.000000
# 50%      70.000000
# 75%      73.000000
# max      82.000000

# %%
september_temp = session.query(Measurement.date, Measurement.tobs).filter(extract('month', Measurement.date)==9).all()
september_temp_df = pd.DataFrame(september_temp, columns=['date','Septemper,℉'])
september_temp_df.set_index('date', inplace=True)
september_temp_df.describe()
# Out:
#        Septemper,℉
# count  1480.000000
# mean     76.164865
# std       3.535178
# min      64.000000
# 25%      74.000000
# 50%      76.000000
# 75%      79.000000
# max      87.000000
